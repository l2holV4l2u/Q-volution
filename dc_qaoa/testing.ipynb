# %%
from pyquil import Program, get_qc
from pyquil.gates import *
from pyquil.quilbase import Declare

# %%
p = Program(
    Declare("ro", "BIT", 2),
    H(0),
    CNOT(0, 1),
    MEASURE(0, ("ro", 0)),
    MEASURE(1, ("ro", 1)),
).wrap_in_numshots_loop(10)

# %%
import os
os.environ["QCS_SETTINGS_APPLICATIONS_QVM_URL"] = "http://127.0.0.1:5001"

# run the program on a QVM
qc = get_qc('9q-square-qvm')
result = qc.run(qc.compile(p)).get_register_map().get("ro")
print(result[0])
print(result[1])
# Out:
# [1 1]
# [1 1]

# %%
from main import main

# %%
main()
# Out:
# usage: ipykernel_launcher.py [-h] [--qaoa] [--qc QC] [--max-size MAX_SIZE]
#                              [--top-t TOP_T] [--method {separator,community}]
#                              [--layers LAYERS] [--shots SHOTS] [--seed SEED]
#                              [--hardware] [--output OUTPUT]
#                              [graph]
# ipykernel_launcher.py: error: unrecognized arguments: --f=/Users/tisornnaphattalung/Library/Jupyter/runtime/kernel-v3981cb2cc2de7954b57d3a496e18dd2589e8f2893.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
